# %% [raw]
# # Introduction
# ## 背景
# 自宅療養者と医師ヘルパーのマッチングに効率化が必要
#
# ## 研究目的
#
#
# ## 応用
# 災害時のヘルパーマッチング
#
# # 関連研究
# ## Vehicle Routing Problem
# mTSP
# 運搬の労力・コストを最小化する試み
# NP-hardなため大規模なデータに向いていない。
#
# - 道のりとユークリッド距離は相関性がある
# - TSPを解く代わりに拠点の分散を使ってみる。
#
# ## K-means
# k-means, k-means++
#
# バランスが取れたアルゴリズム
#
# - minmax k-means algorithm
# - cluster size restricted algorithm
# - balanced k-means

# %% [raw]
# define params
# x
# n i
# k j
#
# 重心関数 = Sum Load of Cluster
# ロード関数 = クラスタサイズ + 分散
# k個の重心uをランダムに配置
#
#
# 1. k-means後、後でロード差から調整
#
# # k-means
# while クラスタが収束
#     クラスタの振り分け
#         L = argmin(of k) Sum_x Sum_n d(x_i,u_j)
#         d = 距離関数
#
#     重心の再配置
#         クラスタの重心を更新
#         for j in k
#             us = [ var(c_j) for j in k ]
#
#         if 残差(sum|x-u|) < 基準(Torelance)
#             クラスタが収束
#
# # ロードの計算
# max_cluster = find max cluster
# min_cluster = find min cluster
#
# max = Load(max_cluster)
# min = Load(min_cluster)
# 最大ロード差 = max / min
#
# while (max / min) > criteria
#     一番外側の点を探す in max_cluster
#     所属クラスタを除く一番近いクラスタに配置
#         一番近いクラスタを探す
#             argmin(Cs, Load(x,u))
#         所属クラスタを変更
#     max,min 再計算
#     max_cluster = find max cluster
#     min_cluster = find min cluster

# %% [raw]
# # クラスタ入れ替え後、ループでまた振り分けで、距離関数で計算することでもどってしまう。
# 振り分け時にロード関数を使えばいいが、計算量が爆発してまう
#
# # 改善策1
# - k-meansのイテレーションの中で、ロードの増分を計算する
#
# 2. k-meansの距離関数を、ロードの差関数に変更。
# ロードの差関数 = 1 * alpha + (1-alpha) * 1/(num+1) * ( num * (mean^2 - mean) + node^2 + node - variance )
#
# 分散のオンライン更新を参考に、改変
# https://mathwords.net/tikujiheikin
#
# # ランダム重心
# us = [u for k]
# # ロード配列
# Loads = [load(u) for k]
#
# load(c, u) = |c| + 分散 #ユーザー関数
# clusters_prev = []
#
# while クラスタが収束しない
#
#     # クラスタの振り分け # O(k*n)
#     d(x,u) = 距離関数 = x - u
#     m = クラスタの大きさ
#     deltaLoad = ロードの差関数(m, u, x)
#
#     clusters[len(x)] = []
#
#     for i in len(x):
#         deltas = []
#         for j in k:
#             m = cluster(j).size
#             delta = deltaLoad(m, vars(j), x[i])
#             deltas.push(delta)
#         cluster_idx = argmin(deltas)
#         clusters.push(cluster_idx)
#
#
#     # 重心の再配置
#     クラスタのLoadを計算、重心を更新
#     for j in k
#         vars.push(var(c_j))
#         Loads.push(ロード関数(クラスタサイズ, 重心との差))
#
#     # 収束判定
#     if 前回とラベルが一致、or カウントが一定
#         クラスタが収束

# %%
# 実装

# ライブラリimport
import numpy as np
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt

# data用意
X, y = make_blobs(n_samples=1000, centers=10, cluster_std=1, n_features=2,random_state=6)

# data可視化

plt.scatter(X[:,0], X[:,1])

# %%
# 2. k-meansの距離関数を、ロードの差関数に変更。
# k-means自体のアルゴリズムを拡張
import itertools 

# load function
def load(num, alpha, variance):
    return alpha * num + (1-alpha) * np.linalg.norm(variance)

# load delta
def load_delta(n, alpha, node, variance, mean):
    mean_1 = (n*mean + node)/(n+1)
    var_1 = (n*(variance+np.square(mean)) + np.square(node))/(n+1) - np.square(mean_1)
    delta_var = var_1 - variance

    return alpha + (1-alpha) * np.linalg.norm(delta_var)

def kload2(data, alpha=0.5,k=4, max_iter=10,random_seed=1):
    #指定したクラスター数分のラベルを繰り返し作成するジェネレータを生成（0,1,2,0,1,2,0,1,2...みたいな感じ
    cycle = itertools.cycle(range(k))
    #各データポイントに対してクラスタのラベルをランダムに割り振る
    labels = np.fromiter(itertools.islice(cycle, data.shape[0]), dtype = int)
    random_state = np.random.RandomState(random_seed)
    random_state.shuffle(labels)
    
    labels_prev = np.zeros(data.shape[0])
    count = 0
    cluster_centers = np.zeros((k, data.shape[1]))
    variances = np.zeros((k, data.shape[1]))
    cluster_sizes = np.zeros(k)
    loads = np.zeros(k)
    
    # クラスタの変化がない、or 最大回数
    while (not np.array_equal(labels, labels_prev) and (count < max_iter)):
        # 判定用変数
        labels_prev = labels.copy()
        count += 1
        
        #その時点での各クラスターの重心を計算する

        
        for j in range(k):
            cluster_nodes = data[labels == j, :]
            cluster_sizes[j] = cluster_nodes.shape[0]
            if cluster_sizes[j] == 0:
                pass
                # variances[j, :] = 0
                # cluster_centers[j, :] = 0
            else:
                variances[j, :] = np.nanvar(cluster_nodes, axis=0)
                cluster_centers[j, :] = np.nanmean(cluster_nodes, axis = 0)
            loads[j] = load(cluster_sizes[j], alpha, variances[j])
            
        #各データポイントと各クラスターの重心間の距離を総当たりで計算する
        
        for i, x in enumerate(data):
            deltas = np.zeros(k)
            for j in range(k):
                # 1 o(1) 
                # deltas[j] = load_delta(cluster_sizes[j], alpha, x, variances[j], cluster_centers[j])
                
                # 2 loadsを再計算する方法
                # o(n/k) 計算量爆発するし、収束しない
                # cluster_nodes = data[labels == j, :]
                # cluster_size = cluster_nodes.shape[0]
                # variance = np.nanvar(cluster_nodes, axis=0)
                # deltas[j] = load(cluster_size, alpha, variance)
                
                # 3 中心点からの距離の方法
                deltas[j] = np.linalg.norm(cluster_centers[j] - x)
            # print(deltas)
            labels[i] = np.argmin(deltas)
            
        # print('cond', np.array_equal(labels, labels_prev), count<max_iter)
        # print(labels_prev[:10], labels[:10])
        # print(count)
        # print("v",variances)
        # print("num",cluster_sizes)
        # print("c", cluster_centers)
        # print("load",loads, np.sum(loads))
        # print(np.var(loads))
    # end while
    return count, cluster_sizes, loads, np.var(loads)

kload2(data=X[:1000], alpha=0.6, k=5, max_iter=50,random_seed=5)
# Out:
# 0.5248022157003788
# 7232.276790934586
# 7998.118553115841
# 8147.294774981987
# 5681.208690831138
# 3544.2267395172466
# 2869.63439282878
# 2920.580439100387
# 3445.3785034640423
# 3643.5600484146257
# 3795.29567387942
# 3930.2168953059736
# 4073.816427284025
# 4192.767369876217
# 4308.410056283512
# 4403.991386877581
# 4502.507128654955
# 4569.613009403802
# 4637.929935785151
# (19,
#  array([366., 101., 101., 301., 131.]),
#  array([222.25168888,  61.18316391,  61.2237478 , 185.00291846,
#          79.83970835]),
#  4637.929935785151)

# %%
# 実験
# ロードの分散を調べる。どれだけいいモデルができたか

print("\nalpha の値を変えて比較")
alphas=[0.01,0.1,0.3,0.5,0.8,0.9,0.99]
for alpha in alphas:
    print(kload2(data=X[:100], alpha=alpha, k=5, max_iter=50,random_seed=5))

print("\nデータの数を変えて比較")
nums=[10,100,500,1000]
for num in nums:
    print(kload2(data=X[:num], alpha=0.8, k=5, max_iter=50,random_seed=4))

print("\n初期のランダムネスを変えて比較")

for num in range(10):
    print(kload2(data=X[:100], alpha=0.8, k=5, max_iter=50,random_seed=num))

# 計算速度、使えるモデルができたか
# Out:
# alpha の値を変えて比較
# 25.68394845423587
# 26.065783029873547
# 9.688660605384165
# 6.442934940059556
# 8.294817188680629
# 10.926526548757355
# 11.265790811939308
# (7, array([17., 14., 30., 18., 21.]), array([ 2.45295443,  3.92853302, 11.08170805,  6.98511272,  2.12577432]), 11.265790811939308)
# 21.22640368118667
# 32.764091955870335
# 11.919693309375665
# 7.525781125983403
# 9.176704141150974
# 11.55376995009725
# 11.80784589462137
# (7, array([17., 14., 30., 18., 21.]), array([ 3.77541312,  4.84412093, 12.80155278,  7.98646611,  3.84161302]), 11.80784589462137)
# 12.840663955285754
# 50.660068569736815
# 17.747867915037077
# 10.638114857730155
# 11.70958056457605
# 13.531797003711414
# 13.843785349017391
# (7, array([17., 14., 30., 18., 21.]), array([ 6.7142102 ,  6.87876072, 16.62342994, 10.21169586,  7.6545879 ]), 13.843785349017391)
# 6.551359160860082
# 72.70893575906112
# 24.776489627383945
# 14.724253933115786
# 15.032977870977138
# 16.315552096517827
# 17.026445636505034
# (7, array([17., 14., 30., 18., 21.]), array([ 9.65300729,  8.91340051, 20.4453071 , 12.43692562, 11.46756279]), 17.026445636505034)
# 1.0482174657376115
# 113.56890637203108
# 37.57026052093948
# 22.679347565517155
# 21.500300486158835
# 22.001924809212944
# 23.950537629783295
# (7, array([17., 14., 30., 18., 21.]), array([14.06120292, 11.96536021, 26.17812284, 15.77477025, 17.18702512]), 23.950537629783295)
# 0.262054366434402
# 129.26534186408335
# 42.43507437213405
# 25.81794811480371
# 24.0513351327074
# 24.300246399707433
# 26.831928710755186
# (7, array([17., 14., 30., 18., 21.]), array([15.53060146, 12.9826801 , 28.08906142, 16.88738512, 19.09351256]), 26.831928710755186)
# 0.0026205436643441347
# 144.27981416743444
# 47.0700024072632
# 28.85083950136443
# 26.516240153337257
# 26.54096019952983
# 29.670292261703235
# (7, array([17., 14., 30., 18., 21.]), array([16.85306015, 13.89826801, 29.80890614, 17.88873851, 20.80935126]), 29.670292261703235)
#
# データの数を変えて比較
# 4.510928635262962
# 0.9763843091229063
# (2, array([3., 2., 3., 1., 1.]), array([2.65986472, 2.50595222, 3.14546352, 0.8       , 0.8       ]), 0.9763843091229063)
# 2.6708358372801366
# 71.8210125391889
# 41.16136718561704
# 40.79130922047305
# 28.415989203759914
# 26.794080785227436
# (6, array([18., 28., 24., 11., 19.]), array([15.77477025, 24.65756505, 19.73262652,  8.97154924, 15.61433794]), 26.794080785227436)
# 1.1665182767333029
# 2297.147659516866
# 1379.8534042951608
# 1180.8444477395003
# 1064.4501397841934
# 1052.2329453633197
# 1040.6657973297783
# 1008.8871266653699
# 960.0617144978802
# 918.2756125785882
# 897.8303437996956
# 879.2782669973394
# (12, array([ 52.,  62., 142., 129., 115.]), array([ 41.9422844 ,  50.08956595, 115.72756833, 104.81237551,
#         92.93521833]), 879.2782669973394)
# 0.07647476004281413
# 20205.796935548016
# 6064.159344829146
# 4724.131814334757
# 4582.905027976807
# 4479.174554033705
# 4359.233376467315
# 4296.272566082908
# 4291.661134354725
# 4336.690186526483
# 4382.516957358894
# 4597.26027288758
# 5085.230817367723
# 5619.019013430459
# 5791.437180249079
# 6019.636636934524
# 6309.321681699936
# 6577.664137705894
# 6815.608941584549
# 7067.333582212819
# 7277.191271822628
# 7481.005036347087
# 7649.361991969534
# 7822.553637314151
# 7940.567131134919
# 8060.667582295753
# (26, array([131., 366., 101., 101., 301.]), array([105.41985417, 294.12584444,  81.09158195,  81.1118739 ,
#        243.00145923]), 8060.667582295753)
#
# 初期のランダムネスを変えて比較
# 0.6267285050230194
# 119.92404258990541
# 21.979647184650407
# 22.481219346058747
# 23.95053762978329
# (5, array([18., 17., 14., 21., 30.]), array([15.77477025, 14.06120292, 11.96536021, 17.18702512, 26.17812284]), 23.95053762978329)
# 0.49914846049923167
# 94.37293384883654
# 87.33636169773224
# (3, array([10.,  8., 17., 35., 30.]), array([ 8.22827846,  6.61680698, 14.06120292, 29.61237223, 26.17812284]), 87.33636169773224)
# 1.8959797967319212
# 78.83615446964741
# 24.436116590467844
# 23.950537629783295
# (4, array([30., 14., 17., 18., 21.]), array([26.17812284, 11.96536021, 14.06120292, 15.77477025, 17.18702512]), 23.950537629783295)
# 0.27814495089644253
# 102.76034615404251
# 34.80307529421601
# 15.320376873006541
# 23.95053762978329
# (5, array([17., 21., 30., 18., 14.]), array([14.06120292, 17.18702512, 26.17812284, 15.77477025, 11.96536021]), 23.95053762978329)
# 2.6708358372801366
# 71.8210125391889
# 41.16136718561704
# 40.79130922047305
# 28.415989203759914
# 26.794080785227436
# (6, array([18., 28., 24., 11., 19.]), array([15.77477025, 24.65756505, 19.73262652,  8.97154924, 15.61433794]), 26.794080785227436)
# 1.0482174657376115
# 113.56890637203108
# 37.57026052093948
# 22.679347565517155
# 21.500300486158835
# 22.001924809212944
# 23.950537629783295
# (7, array([17., 14., 30., 18., 21.]), array([14.06120292, 11.96536021, 26.17812284, 15.77477025, 17.18702512]), 23.950537629783295)
# 2.1688119033478674
# 223.27934336862913
# 86.41776815437034
# 10.38817919067039
# 2.040944090161526
# 0.7167512175835076
# 3.5266024284589066
# 18.943272664510214
# 34.49195528692852
# (9, array([21., 30., 22., 10., 17.]), array([17.5901868 , 26.17812284, 19.27614403,  8.22827846, 14.57255509]), 34.49195528692852)
# 2.1204663606271064
# 108.58347836232568
# 42.81960132296581
# 47.079837831626186
# (4, array([17., 19., 35., 18., 11.]), array([14.06120292, 15.61433794, 29.61237223, 15.77477025,  8.97154924]), 47.079837831626186)
# 0.2643228702620267
# 178.44012975706565
# 61.61666953285972
# 46.06583467103966
# 39.66947464708439
# 33.77476778664691
# 35.49882642754554
# 38.04435812499572
# (8, array([33., 11., 19., 19., 18.]), array([28.0040121 ,  8.97154924, 15.61433794, 15.8215782 , 15.77477025]), 38.04435812499572)
# 0.2772960633673778
# 145.83119282638216
# 41.13672060648669
# 15.744624532583606
# 25.315230469509856
# 23.950537629783295
# (6, array([30., 14., 17., 18., 21.]), array([26.17812284, 11.96536021, 14.06120292, 15.77477025, 17.18702512]), 23.950537629783295)

# %%
from sklearn.cluster import KMeans

# 各種パラメータ定義


# load function

def load(points, alpha):
    variance = np.var(points, axis=0) # o(n)
    return alpha * points.shape[0] + (1-alpha) * np.linalg.norm(variance)

# k-means 1の方法
def kload(data, alpha=0.5, k=2, radius=0.1, adj_k=2,  max_iter=10):
    kmeans = KMeans(n_clusters=k).fit(data)
    
    labels = np.copy(kmeans.labels_)
    inertia = kmeans.inertia_
    centers = kmeans.cluster_centers_

    iter_count = 0
    radius_prev = np.inf
    delta_prev = np.inf
    delta_load = np.inf
    while True: 
        iter_count += 1

        # クラスタ再配置 based on load func
        clusters = np.array([ data[labels==j] for j in range(0,k)])
        loads = np.array([load(cluster, alpha) for cluster in clusters])
        # print("loads", loads)

        # ロードの計算
        max_cluster_idx = np.argmax(loads)
        min_cluster_idx = np.argmin(loads)
        max_load = loads[max_cluster_idx]
        min_load = loads[min_cluster_idx]
        # delta_load = max_load / min_load

        variance_load = np.linalg.norm(np.var(loads))
        delta_load = np.linalg.norm(np.var(loads))

        if (radius_prev < radius) | (max_iter < iter_count):
            break
        radius_prev = abs(delta_load - delta_prev)
        delta_prev = delta_load
        
        # クラスタを大きい順に並べる
        cluster_sorted_idx = np.argsort(-loads)[:adj_k]
        # 各クラスタの大きい点を次に近いクラスタに移す。
        for j in cluster_sorted_idx:
            all_norms = np.linalg.norm(data - centers[j], axis=1)
            idxs = np.array(np.where(labels == j)).flatten()
            child_idx = np.argmax(all_norms[idxs])
            outmost_idx = idxs[child_idx]
            
            centers_wo_belong = np.copy(centers)
            centers_wo_belong[j] = np.full(data.shape[1], np.inf)
            
            nearest_cluster_idx = np.argmin(np.linalg.norm(centers_wo_belong - data[outmost_idx], axis=1))
            labels[outmost_idx] = nearest_cluster_idx

    return iter_count, loads, variance_load


# 調整用最大クラスタ数 adj_k を変えて実験。データによって違うが、1,2あたりが最適値
for adj_k in range(5):
    data = kload(data=X[:1000], alpha=0.9, k=8, adj_k=adj_k, radius=0.2, max_iter=100 ) 
    print(data)


# 評価. 可視化、ロードの分散具合、計算量、
# k, alpha, データ数, 次元数を変えてみて

# 発展
# ロード関数を変えれば、重みつきのデータにも対応。
# クラスタ入れ替え時に、一つではなくbulkでもいい
# Out:
# /tmp/ipykernel_9857/2195116123.py:28: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   clusters = np.array([ data[labels==j] for j in range(0,k)])
# /tmp/ipykernel_9857/2195116123.py:28: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   clusters = np.array([ data[labels==j] for j in range(0,k)])
# /tmp/ipykernel_9857/2195116123.py:28: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   clusters = np.array([ data[labels==j] for j in range(0,k)])
# (3, array([136.10666728, 178.4087776 ,  90.14431872,  91.04051917,
#         91.02771082, 133.43952709,  90.11890085,  91.02478451]), 965.3667597148319)
# (39, array([145.95026601, 135.20705252,  91.02771082, 146.14198695,
#         90.14431872, 108.45267947,  92.92919361,  91.92527748]), 568.6838250821238)
# (7, array([136.1526728 ,  90.14431872, 174.79715676,  91.93456556,
#         91.96967129, 134.29999089,  91.04579098,  91.02771082]), 897.6174101593149)
# (7, array([ 91.93456556, 175.69923757,  90.14431872,  91.96967129,
#        136.15343656,  91.04579098,  91.02771082, 133.39728199]), 906.9550057815687)
# (101, array([ 90.14431872, 136.10666728, 178.4087776 ,  90.11890085,
#        133.43952709,  91.02771082,  91.04051917,  91.02478451]), 965.3667597148319)
# /tmp/ipykernel_9857/2195116123.py:28: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   clusters = np.array([ data[labels==j] for j in range(0,k)])
# /tmp/ipykernel_9857/2195116123.py:28: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   clusters = np.array([ data[labels==j] for j in range(0,k)])

# %%
np.zeros((5))
# Out:
# array([0., 0., 0., 0., 0.])

# %%
np.var([0])
# Out:
# 0.0
